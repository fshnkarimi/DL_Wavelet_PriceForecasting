# %%
# !git add .
# !git commit -m 'first commit'
# Out:
# [master (root-commit) 42ad81d] first commit
#  2 files changed, 2 insertions(+)
#  create mode 100644 Arima.ipynb
#  create mode 100644 git.ipynb

# %%
# !git pull origin master
# Out:
# From https://github.com/fshnkarimi/DL_Wavelet_PriceForecasting
#  * branch            master     -> FETCH_HEAD
# Already up to date.

# %%
# !git push origin master
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 183.16 KiB | 8.33 MiB/s, done.
# Total 4 (delta 0), reused 0 (delta 0)
# remote:
# remote: Create a pull request for 'master' on GitHub by visiting:
# remote:      https://github.com/fshnkarimi/DL_Wavelet_PriceForecasting/pull/new/master
# remote:
# To https://github.com/fshnkarimi/DL_Wavelet_PriceForecasting.git
#  * [new branch]      master -> master
