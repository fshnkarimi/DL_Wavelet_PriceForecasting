# %%
# !pwd
# Out:
# /content/drive/My Drive/Time_series_forecasting

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My\ Drive/
# Out:
# Mounted at /content/drive
# /content/drive/My Drive

# %%
# %cd Time_series_forecasting/
# Out:
# /content/drive/My Drive/Time_series_forecasting

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/Time_series_forecasting/.git/

# %%
# !git remote add origin https://fshnkarimi:Fshnkarimi1988@github.com/fshnkarimi/DL_Wavelet_PriceForecasting.git
# !git remote -v
# Out:
# origin	https://fshnkarimi:Fshnkarimi1988@github.com/fshnkarimi/DL_Wavelet_PriceForecasting.git (fetch)
# origin	https://fshnkarimi:Fshnkarimi1988@github.com/fshnkarimi/DL_Wavelet_PriceForecasting.git (push)

# %%
# !git config --global user.email 'afshinkarimi67@gmail.com'
# !git config --global user.name 'fshnkarimi'
