# %%
# !git add .
# !git commit -m 'LSTM Added'
# Out:
# [master 41a55d3] small changes
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite Arima.ipynb (95%)
#  rewrite git.ipynb (87%)

# %%
# !git pull origin master
# Out:
# From https://github.com/fshnkarimi/DL_Wavelet_PriceForecasting
#  * branch            master     -> FETCH_HEAD
# Already up to date.

# %%
# !git push origin master
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.18 KiB | 301.00 KiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/fshnkarimi/DL_Wavelet_PriceForecasting.git
#    11eedba..41a55d3  master -> master

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git config --global user.email 'afshinkarimi67@gmail.com'
# !git config --global user.name 'fshnkarimi'
