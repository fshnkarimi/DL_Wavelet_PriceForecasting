# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive/{Your_Directory}/
# Out:
# /content/gdrive/MyDrive/Time_series_forecasting

# %%
# !git config --global user.email 'afshinkarimi67@gmail.com'
# !git config --global user.name 'fshnkarimi'

# %%
# !git add .
# !git commit -m 'LSTM Added'

# %%
# !git pull origin master

# %%
# !git push origin master
